# %%
import pandas as pd

# %%
df = pd.read_csv("../evaluation_samples/mos_results.csv")
df.head()

# %%
average_ratings = df.groupby("model")["rating"].mean()
print(average_ratings)

# %%
print(len(df["listener"].unique()))
